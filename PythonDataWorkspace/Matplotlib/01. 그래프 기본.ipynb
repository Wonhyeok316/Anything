# %% [markdown]
# # Matplotlib
# 다양한 형태의 그래프를 통해서 데이터 시각화를 할 수 있는 라이브러리

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## 그래프 기본

# %%
x = [1, 2, 3]
y = [2, 4, 8]

plt.plot(x, y)

# %%
print(plt.plot(x, y))
# Out:
# [<matplotlib.lines.Line2D object at 0x000001D9EFE17438>]

# %%
plt.plot(x, y)
plt.show()

# %% [markdown]
# ## Title 설정

# %%
plt.plot(x, y)
plt.title('Line Graph')
# Out:
# Text(0.5, 1.0, 'Line Graph')

# %%
plt.plot(x, y)
plt.title('꺾은선 그래프')
# Out:
# Text(0.5, 1.0, '꺾은선 그래프')
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 44734 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 51008 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 49440 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 44536 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 47000 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 54532 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 44734 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 51008 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 49440 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 44536 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 47000 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 54532 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %% [markdown]
# ## 한글 폰트 설정

# %%
import matplotlib
matplotlib.rcParams['font.family'] ='Yu Gothic' # Windows
matplotlib.rcParams['font.size'] = 15

# %%
import matplotlib.font_manager as fm
fm.fontManager.ttflist # 사용가능한 폰트 확인
[f.name for f in fm.fontManager.ttflist]
# Out:
# ['cmsy10',
#  'cmb10',
#  'STIXSizeTwoSym',
#  'DejaVu Sans Mono',
#  'DejaVu Serif',
#  'cmss10',
#  'cmtt10',
#  'STIXNonUnicode',
#  'STIXNonUnicode',
#  'STIXSizeThreeSym',
#  'DejaVu Serif',
#  'DejaVu Sans Mono',
#  'STIXSizeFourSym',
#  'STIXSizeTwoSym',
#  'DejaVu Sans',
#  'DejaVu Sans',
#  'DejaVu Sans Mono',
#  'DejaVu Serif',
#  'DejaVu Sans',
#  'cmr10',
#  'cmex10',
#  'STIXNonUnicode',
#  'STIXSizeFiveSym',
#  'DejaVu Serif Display',
#  'DejaVu Sans Mono',
#  'STIXGeneral',
#  'STIXGeneral',
#  'DejaVu Serif',
#  'DejaVu Sans',
#  'DejaVu Sans Display',
#  'cmmi10',
#  'STIXSizeOneSym',
#  'STIXGeneral',
#  'STIXSizeThreeSym',
#  'STIXGeneral',
#  'STIXSizeOneSym',
#  'STIXNonUnicode',
#  'STIXSizeFourSym',
#  'Palatino Linotype',
#  'Symbol',
#  'Yu Gothic',
#  'Leelawadee UI',
#  'Segoe UI',
#  'Verdana',
#  'Segoe UI',
#  'Corbel',
#  'Yu Gothic',
#  'Webdings',
#  'HoloLens MDL2 Assets',
#  'Comic Sans MS',
#  'Segoe UI',
#  'Constantia',
#  'Malgun Gothic',
#  'Microsoft JhengHei',
#  'Microsoft Himalaya',
#  'Myanmar Text',
#  'Corbel',
#  'Microsoft Yi Baiti',
#  'Times New Roman',
#  'Segoe MDL2 Assets',
#  'Segoe Script',
#  'Malgun Gothic',
#  'Mongolian Baiti',
#  'Candara',
#  'Segoe UI',
#  'Bahnschrift',
#  'Arial',
#  'Impact',
#  'Gadugi',
#  'MV Boli',
#  'Microsoft YaHei',
#  'Javanese Text',
#  'Verdana',
#  'SimSun',
#  'Lucida Console',
#  'Segoe UI',
#  'Ink Free',
#  'HCR Batang',
#  'Microsoft YaHei',
#  'Segoe UI',
#  'SimSun-ExtB',
#  'Palatino Linotype',
#  'NanumGothic',
#  'Sitka Small',
#  'Trebuchet MS',
#  'Constantia',
#  'Sitka Small',
#  'Tahoma',
#  'Nirmala UI',
#  'Consolas',
#  'NanumGothic',
#  'Hancom Gothic',
#  'Franklin Gothic Medium',
#  'NewJumja',
#  'Candara',
#  'Gadugi',
#  'Trebuchet MS',
#  'Calibri',
#  'Georgia',
#  'Calibri',
#  'Arial',
#  'HCR Batang Ext',
#  'Corbel',
#  'Trebuchet MS',
#  'Cambria',
#  'HyhwpEQ',
#  'Segoe UI Historic',
#  'Candara',
#  'Courier New',
#  'Verdana',
#  'Candara',
#  'Segoe UI',
#  'Courier New',
#  'Segoe Script',
#  'Batang',
#  'Arial',
#  'HCR Batang ExtB',
#  'Trebuchet MS',
#  'Palatino Linotype',
#  'HSBRL01',
#  'Microsoft Tai Le',
#  'Microsoft Sans Serif',
#  'Leelawadee UI',
#  'Microsoft PhagsPa',
#  'Ebrima',
#  'Wingdings',
#  'Consolas',
#  'Ebrima',
#  'Tahoma',
#  'Segoe UI',
#  'Microsoft PhagsPa',
#  'Verdana',
#  'HSBRL13',
#  'Candara',
#  'Gabriola',
#  'Hancom Gothic',
#  'Sitka Small',
#  'Malgun Gothic',
#  'Calibri',
#  'HSBRL02',
#  'Segoe UI',
#  'Microsoft New Tai Lue',
#  'Yu Gothic',
#  'Segoe UI Emoji',
#  'Consolas',
#  'HSBRL11',
#  'Cambria',
#  'Nirmala UI',
#  'Microsoft YaHei',
#  'Lucida Sans Unicode',
#  'Constantia',
#  'HancomEQN',
#  'HCR Batang',
#  'Segoe UI',
#  'HSBRL12',
#  'Courier New',
#  'Segoe UI Symbol',
#  'Georgia',
#  'Cambria',
#  'Marlett',
#  'Arial',
#  'Cambria',
#  'Candara',
#  'MS Gothic',
#  'HCR Batang ExtB',
#  'Arial',
#  'Times New Roman',
#  'Haan Wing2',
#  'Constantia',
#  'NanumGothic',
#  'HCR Dotum',
#  'Comic Sans MS',
#  'Comic Sans MS',
#  'Yu Gothic',
#  'Segoe UI',
#  'Calibri',
#  'HSBRL03',
#  'Georgia',
#  'Nirmala UI',
#  'Microsoft JhengHei',
#  'HCR Dotum Ext',
#  'Calibri',
#  'HCR Dotum',
#  'Microsoft JhengHei',
#  'Corbel',
#  'Sylfaen',
#  'Leelawadee UI',
#  'Palatino Linotype',
#  'Segoe UI',
#  'Myanmar Text',
#  'Microsoft Tai Le',
#  'MingLiU-ExtB',
#  'Corbel',
#  'Times New Roman',
#  'Georgia',
#  'Sitka Small',
#  'Calibri',
#  'Courier New',
#  'Times New Roman',
#  'Corbel',
#  'Segoe Print',
#  'Consolas',
#  'Microsoft New Tai Lue',
#  'Segoe Print',
#  'Franklin Gothic Medium',
#  'Comic Sans MS',
#  'Gulim']

# %%
plt.plot(x, y)
plt.title('꺾은 선 그래프')
# Out:
# Text(0.5, 1.0, '꺾은 선 그래프')

# %%
plt.plot([-1, 0, 1], [-5, -1, 2])
plt.show()
